# %%
import torch
import torch.optim as optim
import pandas as pd
import numpy as np

# %%
RETOS_BEBRASK_dataset = pd.read_excel("RETOS_BEBRASK_long.xlsx")

# %%
rating_columns = [col for col in RETOS_BEBRASK_dataset.columns if 'Rating0' in col]
fulfilled_columns = [col for col in RETOS_BEBRASK_dataset.columns if 'Fulfilled' in col]
actions_dataset = RETOS_BEBRASK_dataset[rating_columns]
states_dataset = RETOS_BEBRASK_dataset[fulfilled_columns]
np.array(actions_dataset.iloc[0].values)

def calculate_rewards(states_df, actions_df):
    # Define the reward mappings for each state and action
    reward_mapping = {
        0: {1: 1.0, 2: 0.0, 3: -0.5, 4: -1.0},
        1: {1: -1.0, 2: -0.5, 3: 0.0, 4: 1.0}
    }
    
    # Initialize an empty DataFrame with the same shape as states_df
    
    rewards_df = pd.DataFrame(index=states_df.index, columns=range(1,46))
    
    # Iterate through each cell in the DataFrame
    for row in range(len(states_df.index)):
        for col in range(len(states_df.columns)):
            state = states_df.iloc[row, col]
            action = actions_df.iloc[row, col]
            # Set the reward using the mapping
            reward = reward_mapping[state][action]
            rewards_df.iloc[row, col] = reward
    
    return rewards_df

rewards_dataset = calculate_rewards(states_dataset, actions_dataset)
rewards_dataset = rewards_dataset.apply(pd.to_numeric, errors='coerce')
actions_dataset= actions_dataset-1

# %%
def calculate_initial_q_values(states, actions, num_states, num_actions):
    # Initialize a DataFrame to count occurrences
    count_matrix = pd.DataFrame(0, index=np.arange(num_states), columns=np.arange(1, num_actions + 1))
    # Populate the count matrix with frequencies
    for state, action in zip(states, actions):
        count_matrix.iloc[state, action] += 1
            
    # Normalize to get probabilities
    normalized_counts = count_matrix.div(count_matrix.sum(axis=1), axis=0)
    return normalized_counts.fillna(0)  # Fill NaN with 0 where division might be undefined

# %%
individual_Q_values = {}

# Iterate over each participant
for participant in states_dataset.index:
    participant_states = states_dataset.loc[participant]
    participant_actions = actions_dataset.loc[participant]
    
    # Calculate normalized counts as initial Q-values
    normalized_counts = calculate_initial_q_values(participant_states, participant_actions, 2, 4)
    
    # Convert to tensor
    Q_values_tensor = torch.tensor(normalized_counts.values+0.01, dtype=torch.float, requires_grad=True)
    
    # Store in dictionary
    individual_Q_values[participant] = Q_values_tensor

    print(f"Initial Q-values for Participant {participant}:")
    print(Q_values_tensor)
# Out:
# Initial Q-values for Participant 0:
# tensor([[0.6211, 0.0656, 0.1767, 0.1767],
#         [0.0100, 0.1581, 0.1581, 0.7137]], requires_grad=True)
# Initial Q-values for Participant 1:
# tensor([[0.3989, 0.4544, 0.1211, 0.0656],
#         [0.0470, 0.2322, 0.4544, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 2:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.1211, 0.1581, 0.3804, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 3:
# tensor([[0.6767, 0.1767, 0.0100, 0.1767],
#         [0.0841, 0.1581, 0.3433, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 4:
# tensor([[0.7322, 0.1767, 0.1211, 0.0100],
#         [0.1211, 0.2693, 0.3063, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 5:
# tensor([[0.6211, 0.3433, 0.0656, 0.0100],
#         [0.0470, 0.1952, 0.4915, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 6:
# tensor([[0.8433, 0.1211, 0.0656, 0.0100],
#         [0.1581, 0.2322, 0.2693, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 7:
# tensor([[0.3989, 0.2878, 0.3433, 0.0100],
#         [0.0841, 0.1211, 0.5656, 0.2693]], requires_grad=True)
# Initial Q-values for Participant 8:
# tensor([[0.6767, 0.2878, 0.0100, 0.0656],
#         [0.3433, 0.1211, 0.1952, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 9:
# tensor([[0.9544, 0.0656, 0.0100, 0.0100],
#         [0.3063, 0.2693, 0.2693, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 10:
# tensor([[0.8989, 0.0656, 0.0656, 0.0100],
#         [0.0100, 0.1581, 0.6396, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 11:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.1581, 0.2693, 0.2322, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 12:
# tensor([[0.5656, 0.3433, 0.0656, 0.0656],
#         [0.0470, 0.0841, 0.3433, 0.5656]], requires_grad=True)
# Initial Q-values for Participant 13:
# tensor([[0.6767, 0.2878, 0.0100, 0.0656],
#         [0.0470, 0.3433, 0.4174, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 14:
# tensor([[0.6767, 0.1211, 0.0656, 0.1767],
#         [0.0100, 0.1211, 0.4174, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 15:
# tensor([[0.7878, 0.1211, 0.0656, 0.0656],
#         [0.1211, 0.3433, 0.3804, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 16:
# tensor([[0.6767, 0.1767, 0.1211, 0.0656],
#         [0.0841, 0.2693, 0.3804, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 17:
# tensor([[0.6211, 0.2322, 0.0656, 0.1211],
#         [0.0470, 0.1581, 0.5285, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 18:
# tensor([[0.8989, 0.1211, 0.0100, 0.0100],
#         [0.0100, 0.2693, 0.4544, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 19:
# tensor([[0.6767, 0.2322, 0.1211, 0.0100],
#         [0.0100, 0.1952, 0.4544, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 20:
# tensor([[0.7322, 0.2322, 0.0100, 0.0656],
#         [0.1211, 0.2322, 0.2322, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 21:
# tensor([[0.7322, 0.2322, 0.0656, 0.0100],
#         [0.0841, 0.2322, 0.4915, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 22:
# tensor([[0.5656, 0.2878, 0.0656, 0.1211],
#         [0.0841, 0.2693, 0.4544, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 23:
# tensor([[0.6211, 0.2878, 0.0100, 0.1211],
#         [0.1952, 0.3063, 0.2693, 0.2693]], requires_grad=True)
# Initial Q-values for Participant 24:
# tensor([[0.6211, 0.2322, 0.1211, 0.0656],
#         [0.2322, 0.2322, 0.2693, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 25:
# tensor([[0.5100, 0.1767, 0.2878, 0.0656],
#         [0.0100, 0.1581, 0.4915, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 26:
# tensor([[0.4544, 0.2878, 0.2322, 0.0656],
#         [0.1952, 0.3804, 0.2322, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 27:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.2322, 0.2322, 0.3433, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 28:
# tensor([[0.5656, 0.2322, 0.2322, 0.0100],
#         [0.0100, 0.2322, 0.3433, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 29:
# tensor([[0.8433, 0.1211, 0.0100, 0.0656],
#         [0.0470, 0.3063, 0.3804, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 30:
# tensor([[0.5656, 0.3433, 0.0656, 0.0656],
#         [0.0470, 0.2322, 0.4174, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 31:
# tensor([[0.5656, 0.1211, 0.2322, 0.1211],
#         [0.0100, 0.1952, 0.5285, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 32:
# tensor([[0.5656, 0.3433, 0.1211, 0.0100],
#         [0.0841, 0.3063, 0.5285, 0.1211]], requires_grad=True)
# Initial Q-values for Participant 33:
# tensor([[0.5100, 0.3989, 0.1211, 0.0100],
#         [0.0100, 0.0841, 0.5285, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 34:
# tensor([[0.6767, 0.3433, 0.0100, 0.0100],
#         [0.0470, 0.2322, 0.4174, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 35:
# tensor([[0.1767, 0.4544, 0.3433, 0.0656],
#         [0.1581, 0.5656, 0.2322, 0.0841]], requires_grad=True)
# Initial Q-values for Participant 36:
# tensor([[0.6211, 0.1767, 0.1767, 0.0656],
#         [0.0470, 0.2693, 0.3804, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 37:
# tensor([[0.6767, 0.0656, 0.1211, 0.1767],
#         [0.0470, 0.3063, 0.4915, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 38:
# tensor([[0.4544, 0.3433, 0.2322, 0.0100],
#         [0.1952, 0.2322, 0.4544, 0.1581]], requires_grad=True)
# Initial Q-values for Participant 39:
# tensor([[0.7322, 0.1211, 0.0100, 0.1767],
#         [0.2322, 0.2322, 0.2693, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 40:
# tensor([[0.5656, 0.1211, 0.1767, 0.1767],
#         [0.0100, 0.0841, 0.2693, 0.6767]], requires_grad=True)
# Initial Q-values for Participant 41:
# tensor([[0.5100, 0.2878, 0.1211, 0.1211],
#         [0.2693, 0.4174, 0.1952, 0.1581]], requires_grad=True)
# Initial Q-values for Participant 42:
# tensor([[0.7322, 0.2322, 0.0656, 0.0100],
#         [0.1581, 0.1952, 0.3433, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 43:
# tensor([[0.3433, 0.4544, 0.1767, 0.0656],
#         [0.0841, 0.3063, 0.2693, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 44:
# tensor([[0.4544, 0.3433, 0.2322, 0.0100],
#         [0.0100, 0.3804, 0.2693, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 45:
# tensor([[0.6211, 0.1211, 0.1767, 0.1211],
#         [0.0470, 0.3063, 0.1952, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 46:
# tensor([[0.5100, 0.4544, 0.0656, 0.0100],
#         [0.0100, 0.2322, 0.4174, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 47:
# tensor([[0.5100, 0.2878, 0.1767, 0.0656],
#         [0.0100, 0.3063, 0.3433, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 48:
# tensor([[0.6767, 0.1211, 0.1767, 0.0656],
#         [0.0841, 0.2322, 0.3063, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 49:
# tensor([[0.6767, 0.2322, 0.0656, 0.0656],
#         [0.0470, 0.1581, 0.4174, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 50:
# tensor([[0.3433, 0.4544, 0.2322, 0.0100],
#         [0.1211, 0.3433, 0.2322, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 51:
# tensor([[0.8989, 0.1211, 0.0100, 0.0100],
#         [0.1581, 0.2322, 0.3804, 0.2693]], requires_grad=True)
# Initial Q-values for Participant 52:
# tensor([[0.5656, 0.1767, 0.0656, 0.2322],
#         [0.0470, 0.3433, 0.1952, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 53:
# tensor([[0.7322, 0.1767, 0.0656, 0.0656],
#         [0.0841, 0.1581, 0.2693, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 54:
# tensor([[0.6211, 0.1767, 0.1211, 0.1211],
#         [0.0100, 0.1581, 0.3804, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 55:
# tensor([[0.7322, 0.1211, 0.1767, 0.0100],
#         [0.1952, 0.1581, 0.4915, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 56:
# tensor([[0.6211, 0.2322, 0.1211, 0.0656],
#         [0.1211, 0.0470, 0.6026, 0.2693]], requires_grad=True)
# Initial Q-values for Participant 57:
# tensor([[0.5656, 0.2878, 0.1211, 0.0656],
#         [0.0100, 0.1952, 0.3063, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 58:
# tensor([[0.9544, 0.0656, 0.0100, 0.0100],
#         [0.2322, 0.3433, 0.3063, 0.1581]], requires_grad=True)
# Initial Q-values for Participant 59:
# tensor([[0.6767, 0.1211, 0.1767, 0.0656],
#         [0.0841, 0.1581, 0.2693, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 60:
# tensor([[0.6767, 0.1211, 0.1767, 0.0656],
#         [0.0100, 0.1581, 0.3433, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 61:
# tensor([[0.8433, 0.1211, 0.0656, 0.0100],
#         [0.0841, 0.1581, 0.3063, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 62:
# tensor([[0.6571, 0.3041, 0.0688, 0.0100],
#         [0.2243, 0.2957, 0.4743, 0.0457]], requires_grad=True)
# Initial Q-values for Participant 63:
# tensor([[0.6767, 0.1767, 0.0656, 0.1211],
#         [0.2322, 0.1581, 0.2322, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 64:
# tensor([[0.5656, 0.3433, 0.1211, 0.0100],
#         [0.1952, 0.3063, 0.3433, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 65:
# tensor([[0.6211, 0.2322, 0.1767, 0.0100],
#         [0.0841, 0.3433, 0.5285, 0.0841]], requires_grad=True)
# Initial Q-values for Participant 66:
# tensor([[0.6211, 0.1767, 0.1211, 0.1211],
#         [0.1211, 0.1211, 0.1952, 0.6026]], requires_grad=True)
# Initial Q-values for Participant 67:
# tensor([[0.5656, 0.3433, 0.0656, 0.0656],
#         [0.0100, 0.2693, 0.3433, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 68:
# tensor([[0.6211, 0.1211, 0.1211, 0.1767],
#         [0.0841, 0.1581, 0.4544, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 69:
# tensor([[0.8433, 0.1211, 0.0656, 0.0100],
#         [0.2693, 0.4174, 0.2322, 0.1211]], requires_grad=True)
# Initial Q-values for Participant 70:
# tensor([[0.6211, 0.1767, 0.1211, 0.1211],
#         [0.0100, 0.1952, 0.4915, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 71:
# tensor([[0.6211, 0.1211, 0.1211, 0.1767],
#         [0.0100, 0.1581, 0.4915, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 72:
# tensor([[0.7322, 0.1211, 0.1211, 0.0656],
#         [0.0841, 0.0470, 0.4915, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 73:
# tensor([[0.5656, 0.0100, 0.3433, 0.1211],
#         [0.0100, 0.0470, 0.4544, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 74:
# tensor([[0.6767, 0.1211, 0.1211, 0.1211],
#         [0.0470, 0.0841, 0.3804, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 75:
# tensor([[0.5656, 0.2878, 0.1211, 0.0656],
#         [0.1952, 0.1952, 0.5285, 0.1211]], requires_grad=True)
# Initial Q-values for Participant 76:
# tensor([[0.4544, 0.2322, 0.2322, 0.1211],
#         [0.0100, 0.0841, 0.3433, 0.6026]], requires_grad=True)
# Initial Q-values for Participant 77:
# tensor([[0.7878, 0.1211, 0.0656, 0.0656],
#         [0.0841, 0.2693, 0.4174, 0.2693]], requires_grad=True)
# Initial Q-values for Participant 78:
# tensor([[0.7322, 0.0656, 0.1211, 0.1211],
#         [0.0100, 0.2322, 0.3063, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 79:
# tensor([[0.4544, 0.1767, 0.3433, 0.0656],
#         [0.1952, 0.1952, 0.4174, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 80:
# tensor([[0.6211, 0.1211, 0.1211, 0.1767],
#         [0.0100, 0.0841, 0.4915, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 81:
# tensor([[0.8433, 0.1767, 0.0100, 0.0100],
#         [0.1581, 0.3433, 0.4544, 0.0841]], requires_grad=True)
# Initial Q-values for Participant 82:
# tensor([[0.8989, 0.1211, 0.0100, 0.0100],
#         [0.0841, 0.1952, 0.3433, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 83:
# tensor([[0.5656, 0.2322, 0.1211, 0.1211],
#         [0.0100, 0.3433, 0.6026, 0.0841]], requires_grad=True)
# Initial Q-values for Participant 84:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.1211, 0.2693, 0.5656, 0.0841]], requires_grad=True)
# Initial Q-values for Participant 85:
# tensor([[0.7878, 0.1211, 0.1211, 0.0100],
#         [0.0470, 0.4915, 0.1952, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 86:
# tensor([[0.6767, 0.0656, 0.2322, 0.0656],
#         [0.1211, 0.1952, 0.2322, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 87:
# tensor([[0.4544, 0.2322, 0.3433, 0.0100],
#         [0.1581, 0.1952, 0.1952, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 88:
# tensor([[0.5656, 0.1211, 0.1767, 0.1767],
#         [0.1211, 0.1581, 0.4174, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 89:
# tensor([[0.6211, 0.2878, 0.0656, 0.0656],
#         [0.0841, 0.3433, 0.3804, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 90:
# tensor([[0.6211, 0.2322, 0.1211, 0.0656],
#         [0.1581, 0.1952, 0.3063, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 91:
# tensor([[0.6211, 0.2878, 0.0656, 0.0656],
#         [0.1211, 0.3433, 0.2693, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 92:
# tensor([[0.7322, 0.0656, 0.1211, 0.1211],
#         [0.1211, 0.1211, 0.4544, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 93:
# tensor([[0.5656, 0.1211, 0.2322, 0.1211],
#         [0.0841, 0.1952, 0.4174, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 94:
# tensor([[0.7878, 0.1211, 0.1211, 0.0100],
#         [0.1581, 0.3433, 0.3433, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 95:
# tensor([[0.6767, 0.0100, 0.2878, 0.0656],
#         [0.0470, 0.1211, 0.4174, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 96:
# tensor([[0.5656, 0.0656, 0.3433, 0.0656],
#         [0.0470, 0.1581, 0.3433, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 97:
# tensor([[0.7322, 0.2322, 0.0656, 0.0100],
#         [0.0470, 0.2693, 0.6026, 0.1211]], requires_grad=True)
# Initial Q-values for Participant 98:
# tensor([[0.5100, 0.2322, 0.2322, 0.0656],
#         [0.3433, 0.2693, 0.3063, 0.1211]], requires_grad=True)
# Initial Q-values for Participant 99:
# tensor([[0.6211, 0.1767, 0.1211, 0.1211],
#         [0.0100, 0.1211, 0.4544, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 100:
# tensor([[0.7322, 0.1767, 0.1211, 0.0100],
#         [0.1581, 0.2693, 0.1581, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 101:
# tensor([[0.6211, 0.2322, 0.1211, 0.0656],
#         [0.0100, 0.1581, 0.3804, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 102:
# tensor([[0.6767, 0.1767, 0.1767, 0.0100],
#         [0.1211, 0.2322, 0.3063, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 103:
# tensor([[0.5656, 0.2878, 0.1211, 0.0656],
#         [0.0841, 0.3433, 0.3804, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 104:
# tensor([[0.6767, 0.3433, 0.0100, 0.0100],
#         [0.0470, 0.3433, 0.4544, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 105:
# tensor([[0.6767, 0.2322, 0.0656, 0.0656],
#         [0.0100, 0.2693, 0.4915, 0.2693]], requires_grad=True)
# Initial Q-values for Participant 106:
# tensor([[0.6767, 0.2322, 0.0656, 0.0656],
#         [0.1211, 0.3063, 0.2693, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 107:
# tensor([[0.6767, 0.2322, 0.1211, 0.0100],
#         [0.0100, 0.3063, 0.3433, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 108:
# tensor([[0.7878, 0.0656, 0.1767, 0.0100],
#         [0.0470, 0.4915, 0.3804, 0.1211]], requires_grad=True)
# Initial Q-values for Participant 109:
# tensor([[0.7878, 0.1211, 0.0100, 0.1211],
#         [0.1581, 0.3804, 0.3063, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 110:
# tensor([[0.6767, 0.0656, 0.2322, 0.0656],
#         [0.0100, 0.1211, 0.2322, 0.6767]], requires_grad=True)
# Initial Q-values for Participant 111:
# tensor([[0.6211, 0.1211, 0.1767, 0.1211],
#         [0.0100, 0.1211, 0.1211, 0.7878]], requires_grad=True)
# Initial Q-values for Participant 112:
# tensor([[0.7322, 0.1211, 0.0656, 0.1211],
#         [0.1581, 0.2322, 0.4174, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 113:
# tensor([[0.7322, 0.2322, 0.0656, 0.0100],
#         [0.0841, 0.3804, 0.4915, 0.0841]], requires_grad=True)
# Initial Q-values for Participant 114:
# tensor([[0.8433, 0.0656, 0.1211, 0.0100],
#         [0.0841, 0.2693, 0.5285, 0.1581]], requires_grad=True)
# Initial Q-values for Participant 115:
# tensor([[0.5656, 0.1767, 0.1767, 0.1211],
#         [0.0100, 0.1211, 0.3063, 0.6026]], requires_grad=True)
# Initial Q-values for Participant 116:
# tensor([[0.5656, 0.2322, 0.1211, 0.1211],
#         [0.0100, 0.3063, 0.2693, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 117:
# tensor([[0.6211, 0.2322, 0.1767, 0.0100],
#         [0.1581, 0.1581, 0.3804, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 118:
# tensor([[0.5656, 0.2878, 0.0100, 0.1767],
#         [0.1211, 0.0841, 0.3063, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 119:
# tensor([[0.5100, 0.4544, 0.0656, 0.0100],
#         [0.0100, 0.1211, 0.4915, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 120:
# tensor([[0.6767, 0.2322, 0.1211, 0.0100],
#         [0.1211, 0.1952, 0.2693, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 121:
# tensor([[0.5100, 0.1767, 0.2878, 0.0656],
#         [0.0100, 0.2693, 0.3063, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 122:
# tensor([[0.6767, 0.0656, 0.1211, 0.1767],
#         [0.0841, 0.0100, 0.3063, 0.6396]], requires_grad=True)
# Initial Q-values for Participant 123:
# tensor([[0.6767, 0.1767, 0.1767, 0.0100],
#         [0.0841, 0.2693, 0.4915, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 124:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.0100, 0.2693, 0.3433, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 125:
# tensor([[0.3433, 0.4544, 0.1211, 0.1211],
#         [0.1211, 0.2693, 0.4915, 0.1581]], requires_grad=True)
# Initial Q-values for Participant 126:
# tensor([[0.7322, 0.1211, 0.1767, 0.0100],
#         [0.1581, 0.3433, 0.3433, 0.1952]], requires_grad=True)
# Initial Q-values for Participant 127:
# tensor([[0.8433, 0.1211, 0.0100, 0.0656],
#         [0.0841, 0.2322, 0.3433, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 128:
# tensor([[0.6767, 0.2878, 0.0656, 0.0100],
#         [0.0100, 0.2322, 0.4174, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 129:
# tensor([[0.5656, 0.2878, 0.1767, 0.0100],
#         [0.0100, 0.1581, 0.3804, 0.4915]], requires_grad=True)
# Initial Q-values for Participant 130:
# tensor([[0.5656, 0.2878, 0.1211, 0.0656],
#         [0.0841, 0.2322, 0.1952, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 131:
# tensor([[0.7878, 0.0656, 0.1211, 0.0656],
#         [0.2693, 0.1211, 0.3433, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 132:
# tensor([[0.4544, 0.3989, 0.1767, 0.0100],
#         [0.0470, 0.1211, 0.4174, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 133:
# tensor([[0.7322, 0.1767, 0.0656, 0.0656],
#         [0.0470, 0.1211, 0.5285, 0.3433]], requires_grad=True)
# Initial Q-values for Participant 134:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.0100, 0.2693, 0.2322, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 135:
# tensor([[0.7322, 0.1211, 0.1211, 0.0656],
#         [0.0841, 0.1211, 0.3804, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 136:
# tensor([[0.6767, 0.2322, 0.0656, 0.0656],
#         [0.0100, 0.4174, 0.3804, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 137:
# tensor([[0.6211, 0.2878, 0.1211, 0.0100],
#         [0.0841, 0.2693, 0.2322, 0.4544]], requires_grad=True)
# Initial Q-values for Participant 138:
# tensor([[0.2322, 0.3989, 0.0656, 0.3433],
#         [0.0100, 0.1952, 0.1952, 0.6396]], requires_grad=True)
# Initial Q-values for Participant 139:
# tensor([[0.7322, 0.1767, 0.0656, 0.0656],
#         [0.0470, 0.2322, 0.3804, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 140:
# tensor([[0.3989, 0.3989, 0.1767, 0.0656],
#         [0.0100, 0.2322, 0.4915, 0.3063]], requires_grad=True)
# Initial Q-values for Participant 141:
# tensor([[0.7322, 0.0656, 0.1767, 0.0656],
#         [0.1211, 0.0470, 0.1211, 0.7507]], requires_grad=True)
# Initial Q-values for Participant 142:
# tensor([[0.7322, 0.1767, 0.0656, 0.0656],
#         [0.1581, 0.2322, 0.4174, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 143:
# tensor([[0.6767, 0.2322, 0.1211, 0.0100],
#         [0.0841, 0.3804, 0.3433, 0.2322]], requires_grad=True)
# Initial Q-values for Participant 144:
# tensor([[0.7878, 0.1767, 0.0656, 0.0100],
#         [0.1211, 0.1211, 0.3804, 0.4174]], requires_grad=True)
# Initial Q-values for Participant 145:
# tensor([[0.6767, 0.2878, 0.0656, 0.0100],
#         [0.1211, 0.3804, 0.3804, 0.1581]], requires_grad=True)
# Initial Q-values for Participant 146:
# tensor([[0.6767, 0.2322, 0.1211, 0.0100],
#         [0.0470, 0.2322, 0.3804, 0.3804]], requires_grad=True)
# Initial Q-values for Participant 147:
# tensor([[0.6767, 0.0656, 0.1767, 0.1211],
#         [0.0841, 0.1952, 0.1952, 0.5656]], requires_grad=True)
# Initial Q-values for Participant 148:
# tensor([[0.5100, 0.3989, 0.1211, 0.0100],
#         [0.0470, 0.2322, 0.2322, 0.5285]], requires_grad=True)
# Initial Q-values for Participant 149:
# tensor([[0.8989, 0.0656, 0.0656, 0.0100],
#         [0.1952, 0.3063, 0.4174, 0.1211]], requires_grad=True)

# %%
# Assuming data is already loaded into these DataFrames
# states_df, actions_df, rewards_df are available

# Define the number of states and actions based on your model setup
num_states = 2  # Adjust based on your data
num_actions = 4  # Adjust based on your data

# Training configuration
learning_rate = 0.02
num_epochs = 250  # For demonstration, use more epochs for actual training

# Dictionary to store results for each participant
results = {}
combined_df = pd.DataFrame({
    'State': states_dataset.stack(),
    'Action': actions_dataset.stack()
}).reset_index()

# Now calculate the frequency of each action for each state
# Normalize counts to get the probability of each action per state
torch.autograd.set_detect_anomaly(True)
for participant in states_dataset.index:
    # Initialize participant-specific Q-values and beta
    
    beta_unconstrained_match = torch.tensor([-2.8], requires_grad=True)  # Initialize around 0 to start with sigmoid(beta) ~ 0.5
    beta_unconstrained_no_match = torch.tensor([-2.8], requires_grad=True)  # Initialize around 0 to start with sigmoid(beta) ~ 0.5

    Q_values = individual_Q_values[participant]

    # Set up optimizer for this participant
    optimizer = optim.Adam([Q_values, beta_unconstrained_match,beta_unconstrained_no_match], lr=learning_rate)

    # Convert participant data from DataFrame to Tensor
    states = torch.tensor(states_dataset.loc[participant].values, dtype=torch.int64)
    actions = torch.tensor(actions_dataset.loc[participant].values, dtype=torch.int64)
    rewards = torch.tensor(rewards_dataset.loc[participant].values, dtype=torch.float32)
    # Training loop for current participant
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        beta_match = torch.sigmoid(beta_unconstrained_match)   
        beta_no_match = torch.sigmoid(beta_unconstrained_no_match)   

        Q_updated = Q_values.clone()
        loss = 0
        for i in range(1,len(states)):
            state = states[i]
            action = actions[i]
            reward = rewards[i-1]
            # Update Q_values on a new tensor to avoid in-place operations
            probabilities = torch.nn.functional.softmax(Q_updated, dim=1)  # Assuming Q_updated is indexed appropriately
            selected_probability = probabilities[state].gather(0, action)
            loss -= torch.log(selected_probability)
            
            
            ## Maybe different beta for sequence s0->s0, s0->s1, s1->s0, s1->s1
            if (states[i-1] == 0):
                beta = beta_no_match
            else:
                beta = beta_match
            new_Q_value = beta * (Q_updated[state, action].clone()-reward) + Q_updated[state, action].clone()
            Q_updated[state, action] = new_Q_value
        
        loss.backward()

        optimizer.step()
    
        #Q_values = Q_updated.detach().clone()  # Detach and clone if Q_values needs to be updated
        #Q_values = torch.clamp(Q_values, min=0, max=1)
        if epoch % 50 == 0 or epoch == num_epochs - 1:  # Print last epoch always
            print(f'Participant {participant}, Epoch {epoch}: Loss = {loss.item()}')
            print("Optimized Q-values:")
            print(Q_values)
            print("Probabilities each Action")
            print(torch.nn.functional.softmax(Q_values,dim=1))
            print("Optimized Beta Match:", beta_match.item())
            print("Optimized Beta No Match:", beta_no_match.item())
    
    
    # Store the final optimized Q-values and beta for each participant
    results[participant] = {'Q_values': Q_values.clone().detach(), 'beta': beta.item()}

# Output the results after training for all participants
print("Training completed. Displaying results for each participant:")
for participant, data in results.items():
    print(f'Participant {participant}: Q-values = {data["Q_values"]}, Beta = {data["beta"]}')
# Out:
# Participant 0, Epoch 0: Loss = 44.903770446777344
# Optimized Q-values:
# tensor([[ 1.1142, -1.0398,  0.0858,  0.0836],
#         [-6.4087,  0.8691,  0.8757,  2.1146]], requires_grad=True)
# Probabilities each Action
# tensor([[5.4633e-01, 6.3386e-02, 1.9535e-01, 1.9493e-01],
#         [1.2599e-04, 1.8242e-01, 1.8362e-01, 6.3384e-01]],
#        grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.05732417479157448
# Optimized Beta No Match: 0.05732417479157448
# Participant 0, Epoch 50: Loss = 41.080108642578125
# Optimized Q-values:
# tensor([[ 0.7288, -1.5073, -0.3635, -0.3488],
#         [-7.3713,  0.7770,  0.7941,  1.8449]], requires_grad=True)
# Probabilities each Action
# tensor([[5.6094e-01, 5.9947e-02, 1.8817e-01, 1.9094e-01],
#         [5.8706e-05, 2.0296e-01, 2.0647e-01, 5.9051e-01]],
#        grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.0336785614490509
# Optimized Beta No Match: 0.03523322194814682
# Participant 0, Epoch 100: Loss = 40.71930694580078
# Optimized Q-values:
# tensor([[ 0.3554, -1.9530, -0.7985, -0.7763],
#         [-8.0979,  0.5235,  0.5346,  1.7195]], requires_grad=True)
# Probabilities each Action
# tensor([[5.7560e-01, 5.7225e-02, 1.8156e-01, 1.8562e-01],
#         [3.3885e-05, 1.8804e-01, 1.9012e-01, 6.2181e-01]],
#        grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.02563386783003807
# Optimized Beta No Match: 0.02790719084441662
# Participant 0, Epoch 150: Loss = 40.56440734863281
# Optimized Q-values:
# tensor([[ 7.7421e-03, -2.3378e+00, -1.1807e+00, -1.1541e+00],
#         [-8.6634e+00,  3.1953e-01,  3.2784e-01,  1.5930e+00]],
#        requires_grad=True)
# Probabilities each Action
# tensor([[5.8363e-01, 5.5909e-02, 1.7783e-01, 1.8263e-01],
#         [2.2490e-05, 1.7916e-01, 1.8066e-01, 6.4016e-01]],
#        grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.021703489124774933
# Optimized Beta No Match: 0.024726714938879013
# Participant 0, Epoch 200: Loss = 40.46611022949219
# Optimized Q-values:
# tensor([[-0.3346, -2.7105, -1.5469, -1.5168],
#         [-9.1286,  0.1405,  0.1469,  1.4593]], requires_grad=True)
# Probabilities each Action
# tensor([[5.8925e-01, 5.4760e-02, 1.7532e-01, 1.8067e-01],
#         [1.6412e-05, 1.7406e-01, 1.7516e-01, 6.5076e-01]],
#        grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.019505513831973076
# Optimized Beta No Match: 0.023780088871717453
# Participant 0, Epoch 249: Loss = 40.381011962890625
# Optimized Q-values:
# tensor([[-0.6826, -3.0889, -1.9141, -1.8814],
#         [-9.5216, -0.0273, -0.0234,  1.3169]], requires_grad=True)
# Probabilities each Action
# tensor([[5.9399e-01, 5.3546e-02, 1.7336e-01, 1.7911e-01],
#         [1.2892e-05, 1.7127e-01, 1.7194e-01, 6.5679e-01]],
#        grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.018283234909176826
# Optimized Beta No Match: 0.024695811793208122
# Participant 1, Epoch 0: Loss = 52.46535873413086
# Optimized Q-values:
# tensor([[ 0.7909,  0.8721, -0.4449, -1.1229],
#         [-1.1116,  0.6578,  1.2994,  0.8064]], requires_grad=True)
# Probabilities each Action
# tensor([[0.3964, 0.4299, 0.1152, 0.0585],
#         [0.0403, 0.2364, 0.4491, 0.2743]], grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.05732417479157448
# Optimized Beta No Match: 0.05732417479157448
# Participant 1, Epoch 50: Loss = 51.1480712890625
# Optimized Q-values:
# tensor([[ 0.2537,  0.3496, -0.9225, -1.6296],
#         [-1.3829,  0.3833,  0.9605,  0.4628]], requires_grad=True)
# Probabilities each Action
# tensor([[0.3904, 0.4298, 0.1204, 0.0594],
#         [0.0424, 0.2478, 0.4414, 0.2683]], grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.029250770807266235
# Optimized Beta No Match: 0.028957705944776535
# Participant 1, Epoch 100: Loss = 50.89207458496094
# Optimized Q-values:
# tensor([[-0.2301, -0.1124, -1.4588, -2.1722],
#         [-1.7284,  0.0504,  0.6888,  0.1614]], requires_grad=True)
# Probabilities each Action
# tensor([[0.3905, 0.4392, 0.1143, 0.0560],
#         [0.0404, 0.2392, 0.4530, 0.2673]], grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.023388609290122986
# Optimized Beta No Match: 0.02261064574122429
# Participant 1, Epoch 150: Loss = 50.65121841430664
# Optimized Q-values:
# tensor([[-0.7506, -0.6210, -2.0106, -2.7362],
#         [-2.0796, -0.2841,  0.3783, -0.1729]], requires_grad=True)
# Probabilities each Action
# tensor([[0.3907, 0.4448, 0.1108, 0.0536],
#         [0.0393, 0.2368, 0.4593, 0.2646]], grad_fn=<SoftmaxBackward0>)
# Optimized Beta Match: 0.02801438234746456
# Optimized Beta No Match: 0.024535536766052246
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 58
#      56         beta = beta_match
#      57     new_Q_value = beta * (Q_updated[state, action].clone()-reward) + Q_updated[state, action].clone()
# ---> 58     Q_updated[state, action] = new_Q_value
#      60 loss.backward()
#      62 optimizer.step()
#
# File ~\anaconda3\envs\CASLabv2\lib\site-packages\torch\fx\traceback.py:68, in format_stack()
#      65     return [current_meta.get("stack_trace", "")]
#      66 else:
#      67     # fallback to traceback.format_stack()
# ---> 68     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File ~\anaconda3\envs\CASLabv2\lib\traceback.py:227, in extract_stack(f, limit)
#     225 if f is None:
#     226     f = sys._getframe().f_back
# --> 227 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     228 stack.reverse()
#     229 return stack
#
# File ~\anaconda3\envs\CASLabv2\lib\traceback.py:379, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     376     result.append(FrameSummary(
#     377         filename, lineno, name, lookup_line=False, locals=f_locals))
#     378 for filename in fnames:
# --> 379     linecache.checkcache(filename)
#     380 # If immediate lookup was desired, trigger lookups now.
#     381 if lookup_lines:
#
# File ~\anaconda3\envs\CASLabv2\lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:
