# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
from scipy import stats
import statsmodels.api as sm
import tqdm
import os

from docx import Document
from docx.shared import Inches

import utils

# %% [markdown]
# ### Preprocessing

# %%
np.random.seed(99) #For reproducibility

#We read the predictive processing data and the scales
predictive_processing_dataset = pd.read_excel("All_Features_dataset.xlsx")
scales = pd.read_excel("scales.xlsx")
scales.drop(["SUBJECT_CODE","Age"],axis=1,inplace=True)

#We join them
common_values = scales['EPRIME_CODE'].unique()
predictive_processing_dataset = predictive_processing_dataset[predictive_processing_dataset['Subject'].isin(common_values)]
feature_scales = pd.merge(left=predictive_processing_dataset, right=scales, left_on="Subject",
                          right_on="EPRIME_CODE").drop(["EPRIME_CODE", "Subject"], axis=1)

# %%
#List of percentiles used
values = list(range(5, 96, 5))

# %%
# List of specific features to examine
specific_features = ["Mean_Rating0","Mean_Rating0_Match","Mean_Rating0_No_Match","Dif_Match","Cor_Pred_Like","Cor_Pred_Like_Match","Cor_Pred_Like_No_Match","Mean_Rating0_Match_Negative","Mean_Rating0_No_Match_Negative","Dif_Negative","Trend_Match","Trend_No_Match",
    "Trend_No_Match_Negative", "Trend_Match_Negative",
    "Cor_Pred_Like_Match_Negative", "Cor_Pred_Like_No_Match_Negative","Mean_Rating0_Match_Happy","Mean_Rating0_No_Match_Happy","Dif_Happy",
    "Trend_No_Match_Happy", "Trend_Match_Happy",
    "Cor_Pred_Like_Match_Happy", "Cor_Pred_Like_No_Match_Happy","Cor_Pred_Like_Negative","Mean_Rating0_Negative","Cor_Pred_Like_Happy","Mean_Rating0_Happy"
]

# %% [markdown]
# ### Bootstrapping with resampling in order to find robust cut-off against different data

# %% [markdown]
# Different Bootstraps depending on the NaN values, only for those that have more than 1 NaN

# %%
# Assuming feature_scales is your DataFrame
def remove_rows_with_nan(df, columns):
    """
    Removes rows that have at least one NaN value in the specified columns.

    Parameters:
    - df (pandas.DataFrame): The DataFrame to filter.
    - columns (list of str): The list of columns to check for NaN values.

    Returns:
    - filtered_df (pandas.DataFrame): A DataFrame with rows containing NaN values in specified columns removed.
    """
    return df.dropna(subset=columns)

# List of columns to check for NaN values
metrics_columns_NaN = ["SPQ", "SPQ_IR", "MSSB_POS", "MSSB_NEG", "MSSB_DES"]

# Remove rows with at least one NaN value in the specified columns
feature_scales_NaN = remove_rows_with_nan(feature_scales, metrics_columns_NaN)

# %% [markdown]
# #### Bootstrap with NaN metrics

# %%
epoch = 150
dict_bootstrap = {}


#dataframes = {}
for i in tqdm.tqdm(range(epoch),desc="Bootstraping"):
    sample_indices = np.random.choice(feature_scales_NaN.index, size=len(feature_scales_NaN), replace=True)
    sample_df = feature_scales_NaN.loc[sample_indices]

    all_dictionary = {}

    # Cluster the bootstrap sample
    for value in values:
    
        # Assuming feature_scales is your DataFrame with features as columns and metrics as rows
        dictionary_distribution = {}
    
        for metric in metrics_columns_NaN:
            dictionary_distribution[metric] = {}

            for feature in specific_features:
                # Drop NaNs for the current metric and feature
                filtered_sample_df = sample_df.dropna(subset=[metric, feature])

                percentile = np.percentile(filtered_sample_df[feature], value)
                if value < 50:
                    above_values = filtered_sample_df[filtered_sample_df[feature] > percentile][metric]
                    below_values = filtered_sample_df[filtered_sample_df[feature] <= percentile][metric]
                else:
                    above_values = filtered_sample_df[filtered_sample_df[feature] >= percentile][metric]
                    below_values = filtered_sample_df[filtered_sample_df[feature] < percentile][metric]
                try:
                    u_stat, p_value = stats.mannwhitneyu(above_values, below_values, alternative='two-sided')
                    # Calculate means
                    high_mean = np.mean(above_values)
                    low_mean = np.mean(below_values)

                    dictionary_distribution[metric][feature] = {
                        'high_mean': high_mean, 'size_high': len(above_values),
                        'low_mean': low_mean, 'size_low': len(below_values),
                        'p_value': p_value
                    }
                except:
                    dictionary_distribution[metric][feature] = {
                        'high_mean': 0, 'size_high': 0,
                        'low_mean': 0, 'size_low': 0,
                        'p_value': 1
                    }

        all_dictionary[value] = dictionary_distribution

    dict_bootstrap[i] = all_dictionary
# Out:
# Bootstraping: 100%|██████████| 150/150 [12:29<00:00,  5.00s/it]

# %%
from collections import defaultdict, Counter

# Aggregate and compute means and variances
aggregate_stats = {value: {
    metric: defaultdict(lambda: {'p_values': [], 'high_means': [], 'low_means': [], 'size_highs': [], 'size_lows': []})
    for metric in metrics_columns_NaN} for value in values}
for i in range(epoch):
    for value in values:
        for metric, features in dict_bootstrap[i][value].items():
            for feature, data in features.items():
                agg = aggregate_stats[value][metric][feature]
                agg['p_values'].append(data['p_value'])
                agg['high_means'].append(data['high_mean'])
                agg['low_means'].append(data['low_mean'])
                agg['size_highs'].append(data['size_high'])
                agg['size_lows'].append(data['size_low'])

# %% [markdown]
# We identify which features are significant in each percentile

# %%
# Identify significant features
significant_features = {value: {} for value in values}
for value in values:
    for metric, features in aggregate_stats[value].items():
        significant_features[value][metric] = {}
        for feature, stat in features.items():
            mean_p = np.mean(stat['p_values'])
            var_p = np.var(stat['p_values'])
            mean_high_mean = np.mean(stat['high_means'])
            var_high_mean = np.var(stat['high_means'])
            mean_low_mean = np.mean(stat['low_means'])
            var_low_mean = np.var(stat['low_means'])
            mean_size_high = np.mean(stat['size_highs'])
            var_size_high = np.var(stat['size_highs'])
            mean_size_low = np.mean(stat['size_lows'])
            var_size_low = np.var(stat['size_lows'])
            if mean_p  < 0.05:  #we use the mean p-value for each pair feature-metric to determine if it is relevant or not               
                significant_features[value][metric][feature] = {
                    'mean_p_value': mean_p,
                    'variance_p_value': var_p,
                    'mean_high_mean': mean_high_mean,
                    'variance_high_mean': var_high_mean,
                    'mean_low_mean': mean_low_mean,
                    'variance_low_mean': var_low_mean,
                    'mean_size_high': mean_size_high,
                    'variance_size_high': var_size_high,
                    'mean_size_low': mean_size_low,
                    'variance_size_low': var_size_low
                }

# Display results
for value in values:
    print(f"\nPercentile Value: {value}%")
    if value in significant_features and significant_features[value]:
        for metric, features in significant_features[value].items():
            print(f"Metric: {metric}")
            for feature, stat in features.items():
                print(f"  Feature: {feature}")
                print(f"    Mean p-value: {stat['mean_p_value']:.4f}, Variance p-value: {stat['variance_p_value']:.4f}")
                print(f"    Mean High Mean: {stat['mean_high_mean']:.2f}, Variance High Mean: {stat['variance_high_mean']:.2f}")
                print(f"    Mean Low Mean: {stat['mean_low_mean']:.2f}, Variance Low Mean: {stat['variance_low_mean']:.2f}")
                print(f"    Mean Size High: {stat['mean_size_high']:.2f}, Variance Size High: {stat['variance_size_high']:.2f}")
                print(f"    Mean Size Low: {stat['mean_size_low']:.2f}, Variance Size Low: {stat['variance_size_low']:.2f}")
    else:
        print("  No significant features at this percentile.")
# Out:
# Percentile Value: 5%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#   Feature: Mean_Rating0_No_Match
#     Mean p-value: 0.0356, Variance p-value: 0.0082
#     Mean High Mean: 2.36, Variance High Mean: 0.06
#     Mean Low Mean: 0.28, Variance Low Mean: 0.26
#     Mean Size High: 112.27, Variance Size High: 5.61
#     Mean Size Low: 7.73, Variance Size Low: 5.61
#
# Percentile Value: 10%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 15%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 20%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 25%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 30%
# Metric: SPQ
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0170, Variance p-value: 0.0047
#     Mean High Mean: 1.85, Variance High Mean: 0.06
#     Mean Low Mean: 3.12, Variance Low Mean: 0.10
#     Mean Size High: 83.62, Variance Size High: 0.54
#     Mean Size Low: 36.38, Variance Size Low: 0.54
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 35%
# Metric: SPQ
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0063, Variance p-value: 0.0015
#     Mean High Mean: 1.74, Variance High Mean: 0.05
#     Mean Low Mean: 3.13, Variance Low Mean: 0.08
#     Mean Size High: 77.50, Variance Size High: 0.69
#     Mean Size Low: 42.50, Variance Size Low: 0.69
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 40%
# Metric: SPQ
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0109, Variance p-value: 0.0019
#     Mean High Mean: 1.70, Variance High Mean: 0.04
#     Mean Low Mean: 3.03, Variance Low Mean: 0.10
#     Mean Size High: 71.27, Variance Size High: 1.13
#     Mean Size Low: 48.73, Variance Size Low: 1.13
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 45%
# Metric: SPQ
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0325, Variance p-value: 0.0109
#     Mean High Mean: 1.72, Variance High Mean: 0.04
#     Mean Low Mean: 2.86, Variance Low Mean: 0.11
#     Mean Size High: 65.33, Variance Size High: 0.87
#     Mean Size Low: 54.67, Variance Size Low: 0.87
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 50%
# Metric: SPQ
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0491, Variance p-value: 0.0119
#     Mean High Mean: 1.74, Variance High Mean: 0.04
#     Mean Low Mean: 2.75, Variance Low Mean: 0.10
#     Mean Size High: 60.65, Variance Size High: 1.00
#     Mean Size Low: 59.35, Variance Size Low: 1.00
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 55%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 60%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 65%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 70%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 75%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 80%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 85%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 90%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES
#
# Percentile Value: 95%
# Metric: SPQ
# Metric: SPQ_IR
# Metric: MSSB_POS
# Metric: MSSB_NEG
# Metric: MSSB_DES

# %% [markdown]
# #### Bootstrap with rest of metrics

# %%
#Metrics with 0 NaN values or 1/2 
metrics_columns = ['PA',
 'NA.',
 'ERQ_CR',
 'ERQ_ES',
 'UPPSP_NU',
 'UPPSP_PU',
 'UPPSP_SS',
 'UPPSP_PMD',
 'UPPSP_PSV',
 'BIS',
 'BAS_RR',
 'BAS_D',
 'BAS_FS',
 'TEPS_AF',
 'TEPS_CF',
 'SHS',
 'FS',
 'LOT_R',
 'RRQ_Rum',
 'RRQ_Ref',
 'ASI_P',
 'ASI_C',
 'ASI_S',
 'ASI_T'             
]

# %%
epoch = 150
dict_bootstrap = {}


#dataframes = {}
for i in tqdm.tqdm(range(epoch),desc="Bootstraping"):
    sample_indices = np.random.choice(feature_scales.index, size=len(feature_scales), replace=True)
    sample_df = feature_scales.loc[sample_indices]

    all_dictionary = {}

    # Cluster the bootstrap sample
    for value in values:
    
        # Assuming feature_scales is your DataFrame with features as columns and metrics as rows
        dictionary_distribution = {}
    
        for metric in metrics_columns:
            dictionary_distribution[metric] = {}
            

            
            for feature in specific_features:
                # Drop NaNs for the current metric and feature
                filtered_sample_df = sample_df.dropna(subset=[metric, feature])
                percentile = np.percentile(filtered_sample_df[feature], value)
                if value < 50:
                    above_values = filtered_sample_df[filtered_sample_df[feature] > percentile][metric]
                    below_values = filtered_sample_df[filtered_sample_df[feature] <= percentile][metric]
                else:
                    above_values = filtered_sample_df[filtered_sample_df[feature] >= percentile][metric]
                    below_values = filtered_sample_df[filtered_sample_df[feature] < percentile][metric]
                try:
                    u_stat, p_value = stats.mannwhitneyu(above_values, below_values, alternative='two-sided')
                    # Calculate means
                    high_mean = np.mean(above_values)
                    low_mean = np.mean(below_values)

                    dictionary_distribution[metric][feature] = {
                        'high_mean': high_mean, 'size_high': len(above_values),
                        'low_mean': low_mean, 'size_low': len(below_values),
                        'p_value': p_value
                    }
                except:
                    dictionary_distribution[metric][feature] = {
                        'high_mean': 0, 'size_high': 0,
                        'low_mean': 0, 'size_low': 0,
                        'p_value': 1
                    }

        all_dictionary[value] = dictionary_distribution

    dict_bootstrap[i] = all_dictionary
# Out:
# Bootstraping: 100%|██████████| 150/150 [1:18:56<00:00, 31.57s/it]

# %%
from collections import defaultdict, Counter

# Aggregate and compute means and variances
aggregate_stats = {value: {
    metric: defaultdict(lambda: {'p_values': [], 'high_means': [], 'low_means': [], 'size_highs': [], 'size_lows': []})
    for metric in metrics_columns} for value in values}
for i in range(epoch):
    for value in values:
        for metric, features in dict_bootstrap[i][value].items():
            for feature, data in features.items():
                agg = aggregate_stats[value][metric][feature]
                agg['p_values'].append(data['p_value'])
                agg['high_means'].append(data['high_mean'])
                agg['low_means'].append(data['low_mean'])
                agg['size_highs'].append(data['size_high'])
                agg['size_lows'].append(data['size_low'])

# %%
# Identify significant features
significant_features = {value: {} for value in values}
for value in values:
    for metric, features in aggregate_stats[value].items():
        significant_features[value][metric] = {}
        for feature, stat in features.items():
            mean_p = np.mean(stat['p_values'])
            var_p = np.var(stat['p_values'])
            mean_high_mean = np.mean(stat['high_means'])
            var_high_mean = np.var(stat['high_means'])
            mean_low_mean = np.mean(stat['low_means'])
            var_low_mean = np.var(stat['low_means'])
            mean_size_high = np.mean(stat['size_highs'])
            var_size_high = np.var(stat['size_highs'])
            mean_size_low = np.mean(stat['size_lows'])
            var_size_low = np.var(stat['size_lows'])
            if mean_p  < 0.05:                
                significant_features[value][metric][feature] = {
                    'mean_p_value': mean_p,
                    'variance_p_value': var_p,
                    'mean_high_mean': mean_high_mean,
                    'variance_high_mean': var_high_mean,
                    'mean_low_mean': mean_low_mean,
                    'variance_low_mean': var_low_mean,
                    'mean_size_high': mean_size_high,
                    'variance_size_high': var_size_high,
                    'mean_size_low': mean_size_low,
                    'variance_size_low': var_size_low
                }


# Display results
for value in values:
    print(f"\nPercentile Value: {value}%")
    if value in significant_features and significant_features[value]:
        for metric, features in significant_features[value].items():
            print(f"Metric: {metric}")
            for feature, stat in features.items():
                print(f"  Feature: {feature}")
                print(f"    Mean p-value: {stat['mean_p_value']:.4f}, Variance p-value: {stat['variance_p_value']:.4f}")
                print(f"    Mean High Mean: {stat['mean_high_mean']:.2f}, Variance High Mean: {stat['variance_high_mean']:.2f}")
                print(f"    Mean Low Mean: {stat['mean_low_mean']:.2f}, Variance Low Mean: {stat['variance_low_mean']:.2f}")
                print(f"    Mean Size High: {stat['mean_size_high']:.2f}, Variance Size High: {stat['variance_size_high']:.2f}")
                print(f"    Mean Size Low: {stat['mean_size_low']:.2f}, Variance Size Low: {stat['variance_size_low']:.2f}")
    else:
        print("  No significant features at this percentile.")
# Out:
# Percentile Value: 5%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 10%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 15%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 20%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
#   Feature: Dif_Negative
#     Mean p-value: 0.0449, Variance p-value: 0.0115
#     Mean High Mean: 3.27, Variance High Mean: 0.01
#     Mean Low Mean: 3.75, Variance Low Mean: 0.02
#     Mean Size High: 118.97, Variance Size High: 0.89
#     Mean Size Low: 31.03, Variance Size Low: 0.89
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 25%
# Metric: PA
#   Feature: Mean_Rating0_Happy
#     Mean p-value: 0.0387, Variance p-value: 0.0109
#     Mean High Mean: 34.08, Variance High Mean: 0.41
#     Mean Low Mean: 31.06, Variance Low Mean: 0.79
#     Mean Size High: 107.77, Variance Size High: 11.18
#     Mean Size Low: 42.23, Variance Size Low: 11.18
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
#   Feature: Dif_Negative
#     Mean p-value: 0.0430, Variance p-value: 0.0095
#     Mean High Mean: 3.26, Variance High Mean: 0.01
#     Mean Low Mean: 3.71, Variance Low Mean: 0.02
#     Mean Size High: 111.25, Variance Size High: 1.15
#     Mean Size Low: 38.75, Variance Size Low: 1.15
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 30%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
#   Feature: Dif_Negative
#     Mean p-value: 0.0407, Variance p-value: 0.0057
#     Mean High Mean: 3.25, Variance High Mean: 0.01
#     Mean Low Mean: 3.66, Variance Low Mean: 0.01
#     Mean Size High: 103.77, Variance Size High: 1.28
#     Mean Size Low: 46.23, Variance Size Low: 1.28
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 35%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
#   Feature: Trend_No_Match_Happy
#     Mean p-value: 0.0321, Variance p-value: 0.0125
#     Mean High Mean: 3.98, Variance High Mean: 0.02
#     Mean Low Mean: 4.40, Variance Low Mean: 0.00
#     Mean Size High: 43.06, Variance Size High: 285.28
#     Mean Size Low: 106.94, Variance Size Low: 285.28
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0217, Variance p-value: 0.0027
#     Mean High Mean: 14.13, Variance High Mean: 0.21
#     Mean Low Mean: 15.96, Variance Low Mean: 0.19
#     Mean Size High: 80.92, Variance Size High: 38.54
#     Mean Size Low: 69.08, Variance Size Low: 38.54
# Metric: RRQ_Rum
# Metric: RRQ_Ref
#   Feature: Dif_Negative
#     Mean p-value: 0.0459, Variance p-value: 0.0099
#     Mean High Mean: 3.23, Variance High Mean: 0.01
#     Mean Low Mean: 3.63, Variance Low Mean: 0.01
#     Mean Size High: 96.10, Variance Size High: 1.81
#     Mean Size Low: 53.90, Variance Size Low: 1.81
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 40%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
#   Feature: Trend_No_Match_Happy
#     Mean p-value: 0.0460, Variance p-value: 0.0108
#     Mean High Mean: 10.99, Variance High Mean: 0.12
#     Mean Low Mean: 12.14, Variance Low Mean: 0.05
#     Mean Size High: 37.99, Variance Size High: 43.52
#     Mean Size Low: 112.01, Variance Size Low: 43.52
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
#   Feature: Trend_No_Match_Happy
#     Mean p-value: 0.0210, Variance p-value: 0.0048
#     Mean High Mean: 3.97, Variance High Mean: 0.01
#     Mean Low Mean: 4.39, Variance Low Mean: 0.00
#     Mean Size High: 37.99, Variance Size High: 43.52
#     Mean Size Low: 112.01, Variance Size Low: 43.52
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0234, Variance p-value: 0.0029
#     Mean High Mean: 14.12, Variance High Mean: 0.21
#     Mean Low Mean: 15.93, Variance Low Mean: 0.21
#     Mean Size High: 78.99, Variance Size High: 57.83
#     Mean Size Low: 71.01, Variance Size Low: 57.83
# Metric: RRQ_Rum
# Metric: RRQ_Ref
#   Feature: Dif_Negative
#     Mean p-value: 0.0448, Variance p-value: 0.0109
#     Mean High Mean: 3.21, Variance High Mean: 0.01
#     Mean Low Mean: 3.61, Variance Low Mean: 0.01
#     Mean Size High: 88.52, Variance Size High: 2.76
#     Mean Size Low: 61.48, Variance Size Low: 2.76
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 45%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
#   Feature: Trend_Match_Happy
#     Mean p-value: 0.0349, Variance p-value: 0.0109
#     Mean High Mean: 7.91, Variance High Mean: 0.08
#     Mean Low Mean: 6.80, Variance Low Mean: 0.07
#     Mean Size High: 78.79, Variance Size High: 9.09
#     Mean Size Low: 70.26, Variance Size Low: 9.93
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
#   Feature: Trend_No_Match_Happy
#     Mean p-value: 0.0487, Variance p-value: 0.0120
#     Mean High Mean: 10.98, Variance High Mean: 0.12
#     Mean Low Mean: 12.15, Variance Low Mean: 0.05
#     Mean Size High: 37.57, Variance Size High: 27.63
#     Mean Size Low: 112.43, Variance Size Low: 27.63
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
#   Feature: Trend_No_Match_Happy
#     Mean p-value: 0.0193, Variance p-value: 0.0044
#     Mean High Mean: 3.96, Variance High Mean: 0.01
#     Mean Low Mean: 4.39, Variance Low Mean: 0.00
#     Mean Size High: 37.57, Variance Size High: 27.63
#     Mean Size Low: 112.43, Variance Size Low: 27.63
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0325, Variance p-value: 0.0096
#     Mean High Mean: 14.07, Variance High Mean: 0.22
#     Mean Low Mean: 15.78, Variance Low Mean: 0.22
#     Mean Size High: 69.39, Variance Size High: 103.21
#     Mean Size Low: 80.61, Variance Size Low: 103.21
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 50%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
#   Feature: Trend_Match_Happy
#     Mean p-value: 0.0357, Variance p-value: 0.0108
#     Mean High Mean: 7.93, Variance High Mean: 0.09
#     Mean Low Mean: 6.81, Variance Low Mean: 0.07
#     Mean Size High: 76.62, Variance Size High: 8.98
#     Mean Size Low: 72.43, Variance Size Low: 8.76
# Metric: UPPSP_PSV
#   Feature: Mean_Rating0_Match
#     Mean p-value: 0.0443, Variance p-value: 0.0142
#     Mean High Mean: 6.50, Variance High Mean: 0.09
#     Mean Low Mean: 7.66, Variance Low Mean: 0.13
#     Mean Size High: 79.65, Variance Size High: 12.59
#     Mean Size Low: 70.35, Variance Size Low: 12.59
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 55%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
#   Feature: Trend_Match_Happy
#     Mean p-value: 0.0282, Variance p-value: 0.0088
#     Mean High Mean: 8.00, Variance High Mean: 0.09
#     Mean Low Mean: 6.87, Variance Low Mean: 0.06
#     Mean Size High: 68.28, Variance Size High: 4.01
#     Mean Size Low: 80.77, Variance Size Low: 3.98
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0478, Variance p-value: 0.0275
#     Mean High Mean: 13.76, Variance High Mean: 5.39
#     Mean Low Mean: 15.53, Variance Low Mean: 6.80
#     Mean Size High: 79.15, Variance Size High: 204.29
#     Mean Size Low: 66.85, Variance Size Low: 155.06
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 60%
# Metric: PA
#   Feature: Mean_Rating0_Match_Negative
#     Mean p-value: 0.0453, Variance p-value: 0.0132
#     Mean High Mean: 34.85, Variance High Mean: 0.66
#     Mean Low Mean: 32.06, Variance Low Mean: 0.41
#     Mean Size High: 62.99, Variance Size High: 9.43
#     Mean Size Low: 87.01, Variance Size Low: 9.43
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
#   Feature: Trend_Match_Happy
#     Mean p-value: 0.0309, Variance p-value: 0.0057
#     Mean High Mean: 8.04, Variance High Mean: 0.11
#     Mean Low Mean: 6.94, Variance Low Mean: 0.05
#     Mean Size High: 60.29, Variance Size High: 0.82
#     Mean Size Low: 88.76, Variance Size Low: 1.18
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0317, Variance p-value: 0.0082
#     Mean High Mean: 14.11, Variance High Mean: 0.24
#     Mean Low Mean: 15.88, Variance Low Mean: 0.22
#     Mean Size High: 76.01, Variance Size High: 79.67
#     Mean Size Low: 73.99, Variance Size Low: 79.67
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 65%
# Metric: PA
#   Feature: Mean_Rating0
#     Mean p-value: 0.0457, Variance p-value: 0.0139
#     Mean High Mean: 35.05, Variance High Mean: 0.73
#     Mean Low Mean: 32.18, Variance Low Mean: 0.41
#     Mean Size High: 55.12, Variance Size High: 4.68
#     Mean Size Low: 94.88, Variance Size Low: 4.68
#   Feature: Mean_Rating0_Match_Negative
#     Mean p-value: 0.0454, Variance p-value: 0.0135
#     Mean High Mean: 34.99, Variance High Mean: 0.70
#     Mean Low Mean: 32.14, Variance Low Mean: 0.41
#     Mean Size High: 57.36, Variance Size High: 11.72
#     Mean Size Low: 92.64, Variance Size Low: 11.72
# Metric: NA.
# Metric: ERQ_CR
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Mean_Rating0_No_Match_Happy
#     Mean p-value: 0.0465, Variance p-value: 0.0147
#     Mean High Mean: 14.08, Variance High Mean: 0.23
#     Mean Low Mean: 15.66, Variance Low Mean: 0.22
#     Mean Size High: 64.59, Variance Size High: 107.76
#     Mean Size Low: 85.41, Variance Size Low: 107.76
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 70%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
#   Feature: Dif_Match
#     Mean p-value: 0.0313, Variance p-value: 0.0085
#     Mean High Mean: 5.19, Variance High Mean: 0.01
#     Mean Low Mean: 4.76, Variance Low Mean: 0.01
#     Mean Size High: 46.19, Variance Size High: 2.42
#     Mean Size Low: 103.81, Variance Size Low: 2.42
#   Feature: Dif_Negative
#     Mean p-value: 0.0312, Variance p-value: 0.0047
#     Mean High Mean: 5.18, Variance High Mean: 0.01
#     Mean Low Mean: 4.77, Variance Low Mean: 0.01
#     Mean Size High: 45.93, Variance Size High: 2.92
#     Mean Size Low: 104.07, Variance Size Low: 2.92
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 75%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
#   Feature: Dif_Match
#     Mean p-value: 0.0195, Variance p-value: 0.0055
#     Mean High Mean: 5.25, Variance High Mean: 0.02
#     Mean Low Mean: 4.77, Variance Low Mean: 0.01
#     Mean Size High: 39.21, Variance Size High: 2.53
#     Mean Size Low: 110.79, Variance Size Low: 2.53
#   Feature: Dif_Negative
#     Mean p-value: 0.0427, Variance p-value: 0.0075
#     Mean High Mean: 5.20, Variance High Mean: 0.02
#     Mean Low Mean: 4.79, Variance Low Mean: 0.01
#     Mean Size High: 39.35, Variance Size High: 3.05
#     Mean Size Low: 110.65, Variance Size Low: 3.05
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 80%
# Metric: PA
#   Feature: Dif_Happy
#     Mean p-value: 0.0205, Variance p-value: 0.0021
#     Mean High Mean: 35.96, Variance High Mean: 1.19
#     Mean Low Mean: 32.40, Variance Low Mean: 0.34
#     Mean Size High: 35.14, Variance Size High: 13.44
#     Mean Size Low: 114.86, Variance Size Low: 13.44
# Metric: NA.
# Metric: ERQ_CR
#   Feature: Dif_Match
#     Mean p-value: 0.0135, Variance p-value: 0.0018
#     Mean High Mean: 5.31, Variance High Mean: 0.02
#     Mean Low Mean: 4.78, Variance Low Mean: 0.01
#     Mean Size High: 31.47, Variance Size High: 3.54
#     Mean Size Low: 118.53, Variance Size Low: 3.54
#   Feature: Dif_Happy
#     Mean p-value: 0.0482, Variance p-value: 0.0145
#     Mean High Mean: 5.24, Variance High Mean: 0.02
#     Mean Low Mean: 4.79, Variance Low Mean: 0.01
#     Mean Size High: 35.14, Variance Size High: 13.44
#     Mean Size Low: 114.86, Variance Size Low: 13.44
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
#   Feature: Dif_Happy
#     Mean p-value: 0.0457, Variance p-value: 0.0117
#     Mean High Mean: 38.54, Variance High Mean: 1.42
#     Mean Low Mean: 34.80, Variance Low Mean: 0.67
#     Mean Size High: 35.14, Variance Size High: 13.44
#     Mean Size Low: 114.86, Variance Size Low: 13.44
# Metric: SHS
# Metric: FS
# Metric: LOT_R
#   Feature: Dif_Happy
#     Mean p-value: 0.0465, Variance p-value: 0.0101
#     Mean High Mean: 16.25, Variance High Mean: 0.49
#     Mean Low Mean: 14.59, Variance Low Mean: 0.12
#     Mean Size High: 35.14, Variance Size High: 13.44
#     Mean Size Low: 114.86, Variance Size Low: 13.44
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 85%
# Metric: PA
#   Feature: Dif_Happy
#     Mean p-value: 0.0287, Variance p-value: 0.0082
#     Mean High Mean: 36.53, Variance High Mean: 1.38
#     Mean Low Mean: 32.52, Variance Low Mean: 0.39
#     Mean Size High: 26.77, Variance Size High: 16.12
#     Mean Size Low: 123.23, Variance Size Low: 16.12
# Metric: NA.
# Metric: ERQ_CR
#   Feature: Dif_Match
#     Mean p-value: 0.0230, Variance p-value: 0.0032
#     Mean High Mean: 5.33, Variance High Mean: 0.02
#     Mean Low Mean: 4.81, Variance Low Mean: 0.01
#     Mean Size High: 24.85, Variance Size High: 3.77
#     Mean Size Low: 125.15, Variance Size Low: 3.77
#   Feature: Mean_Rating0_Match_Happy
#     Mean p-value: 0.0321, Variance p-value: 0.0066
#     Mean High Mean: 5.29, Variance High Mean: 0.02
#     Mean Low Mean: 4.79, Variance Low Mean: 0.01
#     Mean Size High: 30.53, Variance Size High: 54.26
#     Mean Size Low: 119.47, Variance Size Low: 54.26
#   Feature: Dif_Happy
#     Mean p-value: 0.0297, Variance p-value: 0.0079
#     Mean High Mean: 5.36, Variance High Mean: 0.03
#     Mean Low Mean: 4.79, Variance Low Mean: 0.01
#     Mean Size High: 26.77, Variance Size High: 16.12
#     Mean Size Low: 123.23, Variance Size Low: 16.12
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
#   Feature: Dif_Match
#     Mean p-value: 0.0334, Variance p-value: 0.0100
#     Mean High Mean: 12.55, Variance High Mean: 0.32
#     Mean Low Mean: 10.55, Variance Low Mean: 0.07
#     Mean Size High: 24.85, Variance Size High: 3.77
#     Mean Size Low: 125.15, Variance Size Low: 3.77
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
# Metric: BAS_RR
# Metric: BAS_D
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 90%
# Metric: PA
#   Feature: Trend_No_Match_Negative
#     Mean p-value: 0.0414, Variance p-value: 0.0064
#     Mean High Mean: 36.73, Variance High Mean: 1.30
#     Mean Low Mean: 32.81, Variance Low Mean: 0.32
#     Mean Size High: 16.26, Variance Size High: 1.86
#     Mean Size Low: 133.74, Variance Size Low: 1.86
#   Feature: Dif_Happy
#     Mean p-value: 0.0411, Variance p-value: 0.0121
#     Mean High Mean: 37.14, Variance High Mean: 1.95
#     Mean Low Mean: 32.72, Variance Low Mean: 0.33
#     Mean Size High: 17.48, Variance Size High: 6.65
#     Mean Size Low: 132.52, Variance Size Low: 6.65
# Metric: NA.
# Metric: ERQ_CR
#   Feature: Dif_Match
#     Mean p-value: 0.0166, Variance p-value: 0.0020
#     Mean High Mean: 5.48, Variance High Mean: 0.03
#     Mean Low Mean: 4.82, Variance Low Mean: 0.01
#     Mean Size High: 16.58, Variance Size High: 4.07
#     Mean Size Low: 133.42, Variance Size Low: 4.07
#   Feature: Mean_Rating0_Match_Happy
#     Mean p-value: 0.0302, Variance p-value: 0.0049
#     Mean High Mean: 5.36, Variance High Mean: 0.02
#     Mean Low Mean: 4.81, Variance Low Mean: 0.01
#     Mean Size High: 22.11, Variance Size High: 23.41
#     Mean Size Low: 127.89, Variance Size Low: 23.41
#   Feature: Dif_Happy
#     Mean p-value: 0.0129, Variance p-value: 0.0020
#     Mean High Mean: 5.51, Variance High Mean: 0.03
#     Mean Low Mean: 4.81, Variance Low Mean: 0.01
#     Mean Size High: 17.48, Variance Size High: 6.65
#     Mean Size Low: 132.52, Variance Size Low: 6.65
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
#   Feature: Dif_Match
#     Mean p-value: 0.0340, Variance p-value: 0.0084
#     Mean High Mean: 12.86, Variance High Mean: 0.39
#     Mean Low Mean: 10.63, Variance Low Mean: 0.08
#     Mean Size High: 16.58, Variance Size High: 4.07
#     Mean Size Low: 133.42, Variance Size Low: 4.07
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
#   Feature: Cor_Pred_Like
#     Mean p-value: 0.0426, Variance p-value: 0.0141
#     Mean High Mean: 24.03, Variance High Mean: 1.02
#     Mean Low Mean: 21.24, Variance Low Mean: 0.09
#     Mean Size High: 15.41, Variance Size High: 0.44
#     Mean Size Low: 134.59, Variance Size Low: 0.44
# Metric: BAS_RR
# Metric: BAS_D
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0225, Variance p-value: 0.0102
#     Mean High Mean: 13.60, Variance High Mean: 0.33
#     Mean Low Mean: 11.65, Variance Low Mean: 0.04
#     Mean Size High: 15.96, Variance Size High: 0.88
#     Mean Size Low: 134.04, Variance Size Low: 0.88
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
# Metric: ASI_C
# Metric: ASI_S
# Metric: ASI_T
#
# Percentile Value: 95%
# Metric: PA
# Metric: NA.
# Metric: ERQ_CR
#   Feature: Dif_Match
#     Mean p-value: 0.0280, Variance p-value: 0.0041
#     Mean High Mean: 5.61, Variance High Mean: 0.04
#     Mean Low Mean: 4.85, Variance Low Mean: 0.01
#     Mean Size High: 8.75, Variance Size High: 1.72
#     Mean Size Low: 141.25, Variance Size Low: 1.72
# Metric: ERQ_ES
# Metric: UPPSP_NU
# Metric: UPPSP_PU
# Metric: UPPSP_SS
# Metric: UPPSP_PMD
# Metric: UPPSP_PSV
# Metric: BIS
#   Feature: Cor_Pred_Like
#     Mean p-value: 0.0193, Variance p-value: 0.0079
#     Mean High Mean: 25.21, Variance High Mean: 0.94
#     Mean Low Mean: 21.30, Variance Low Mean: 0.09
#     Mean Size High: 8.61, Variance Size High: 0.73
#     Mean Size Low: 141.39, Variance Size Low: 0.73
#   Feature: Cor_Pred_Like_No_Match
#     Mean p-value: 0.0302, Variance p-value: 0.0100
#     Mean High Mean: 24.82, Variance High Mean: 1.07
#     Mean Low Mean: 21.33, Variance Low Mean: 0.09
#     Mean Size High: 8.43, Variance Size High: 0.50
#     Mean Size Low: 141.57, Variance Size Low: 0.50
#   Feature: Cor_Pred_Like_Negative
#     Mean p-value: 0.0321, Variance p-value: 0.0096
#     Mean High Mean: 24.71, Variance High Mean: 1.03
#     Mean Low Mean: 21.33, Variance Low Mean: 0.08
#     Mean Size High: 8.49, Variance Size High: 0.74
#     Mean Size Low: 141.51, Variance Size Low: 0.74
# Metric: BAS_RR
# Metric: BAS_D
#   Feature: Trend_Match_Negative
#     Mean p-value: 0.0278, Variance p-value: 0.0051
#     Mean High Mean: 14.01, Variance High Mean: 0.41
#     Mean Low Mean: 11.72, Variance Low Mean: 0.03
#     Mean Size High: 8.66, Variance Size High: 0.88
#     Mean Size Low: 141.34, Variance Size Low: 0.88
# Metric: BAS_FS
# Metric: TEPS_AF
# Metric: TEPS_CF
# Metric: SHS
# Metric: FS
# Metric: LOT_R
# Metric: RRQ_Rum
# Metric: RRQ_Ref
# Metric: ASI_P
#   Feature: Dif_Match
#     Mean p-value: 0.0265, Variance p-value: 0.0074
#     Mean High Mean: 1.55, Variance High Mean: 0.35
#     Mean Low Mean: 4.89, Variance Low Mean: 0.13
#     Mean Size High: 8.75, Variance Size High: 1.72
#     Mean Size Low: 140.17, Variance Size Low: 2.37
#   Feature: Dif_Negative
#     Mean p-value: 0.0387, Variance p-value: 0.0135
#     Mean High Mean: 1.61, Variance High Mean: 0.60
#     Mean Low Mean: 4.89, Variance Low Mean: 0.13
#     Mean Size High: 8.86, Variance Size High: 0.99
#     Mean Size Low: 140.06, Variance Size Low: 1.87
# Metric: ASI_C
#   Feature: Dif_Negative
#     Mean p-value: 0.0434, Variance p-value: 0.0084
#     Mean High Mean: 0.96, Variance High Mean: 0.19
#     Mean Low Mean: 3.70, Variance Low Mean: 0.14
#     Mean Size High: 8.86, Variance Size High: 0.99
#     Mean Size Low: 140.19, Variance Size Low: 1.95
# Metric: ASI_S
# Metric: ASI_T
#   Feature: Dif_Negative
#     Mean p-value: 0.0346, Variance p-value: 0.0068
#     Mean High Mean: 7.81, Variance High Mean: 5.36
#     Mean Low Mean: 16.98, Variance Low Mean: 0.99
#     Mean Size High: 8.86, Variance Size High: 0.99
#     Mean Size Low: 139.11, Variance Size Low: 2.91
